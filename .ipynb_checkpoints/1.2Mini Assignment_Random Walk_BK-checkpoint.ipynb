# %% [markdown]
# ## Mini Assignment
# - Define random walk in 2D
# - Create a random walk data and save data to file (json/csv)
# - Create a plot for random walk in 2D as save the plot as (pdf/png) file

# %% [markdown]
# ### Solution

# %%
''' Importing libraries'''
import matplotlib.pyplot as plt
import seaborn as sns
import random as random
import numpy as np
import pandas as pd
import random as random
# %matplotlib inline
sns.set()

# %% [markdown]
# ### A. Random walk data in 2D(*Using Iteration*)

# %%
'''if you are in (xi,yi) position go to (xf,yf)'''

'''set up xi,yi'''
xi = 1          # Assigning random position (1,-1) other than (0,0) since(0,o) does not show show random walk
yi = -1         # with given random walk conditions

'''store x and y into X and Y list'''
X = [xi]
Y = [yi]

''' iterate to N steps using for loop'''
for t in range(1000):
        direction =  random.choice(['x','y'])
        if direction == 'x':
            r = random.choice([-1,1])
            xf = X[t-1] + r*xi
            yf = Y[t-1]
        if direction == 'y':
            r = random.choice([-1,1])
            yf = Y[t-1] + r*yi
            xf = X[t-1]
    
        '''remember to update X and Y in every loop'''
        X.append(xf)
        Y.append(yf)
print(X,Y)
# Out:
# [1, 2, 2, 1, 2, 2, 3, 1, 4, 1, 4, 0, 5, 1, 5, 1, 4, 1, 4, 0, 4, -1, 4, 0, 3, 0, 3, 0, 3, 0, 2, -1, 2, -1, 1, -1, 1, -2, 2, -3, 2, -4, 2, -5, 2, -5, 2, -6, 3, -5, 4, -4, 4, -4, 4, -4, 3, -3, 3, -4, 2, -4, 2, -4, 2, -3, 1, -2, 2, -1, 2, -2, 3, -1, 3, -2, 2, -3, 1, -2, 0, -2, 0, -3, 0, -3, 1, -3, 1, -3, 0, -4, 1, -4, 2, -5, 2, -6, 1, -5, 1, -5, 1, -5, 1, -5, 0, -6, -1, -6, -2, -7, -2, -6, -1, -7, -2, -6, -2, -5, -2, -5, -2, -4, -2, -4, -3, -3, -3, -4, -2, -3, -2, -3, -1, -2, -1, -1, -1, -2, -2, -2, -2, -2, -2, -2, -1, -3, -2, -2, -2, -3, -3, -4, -2, -4, -2, -3, -2, -3, -1, -3, -1, -3, -1, -2, 0, -2, 0, -3, 0, -4, -1, -5, -1, -4, -1, -4, -2, -4, -2, -5, -2, -4, -2, -4, -1, -4, -1, -4, -2, -5, -3, -5, -4, -5, -4, -6, -4, -5, -4, -5, -4, -5, -4, -6, -4, -5, -4, -5, -4, -6, -5, -7, -5, -7, -5, -6, -5, -6, -4, -5, -4, -5, -3, -5, -3, -5, -3, -6, -4, -6, -4, -6, -3, -5, -4, -6, -3, -5, -3, -4, -4, -3, -3, -2, -4, -3, -4, -2, -4, -2, -4, -2, -4, -2, -4, -2, -5, -2, -5, -2, -5, -2, -5, -3, -6, -4, -6, -5, -5, -6, -5, -5, -5, -5, -6, -5, -7, -4, -6, -4, -6, -3, -6, -4, -7, -4, -7, -4, -7, -5, -7, -6, -7, -5, -8, -5, -8, -4, -9, -4, -9, -4, -9, -4, -9, -4, -9, -4, -9, -5, -9, -5, -8, -6, -7, -6, -7, -6, -7, -5, -6, -4, -7, -4, -8, -3, -9, -3, -10, -3, -10, -3, -11, -4, -10, -4, -10, -4, -10, -4, -11, -5, -11, -6, -11, -5, -11, -6, -11, -6, -10, -6, -10, -6, -11, -5, -11, -6, -11, -6, -11, -6, -12, -6, -12, -7, -12, -6, -12, -7, -13, -6, -12, -6, -12, -7, -13, -8, -12, -7, -13, -6, -13, -7, -14, -8, -14, -8, -15, -8, -15, -8, -15, -8, -15, -8, -14, -7, -15, -8, -16, -9, -16, -9, -16, -8, -17, -9, -18, -9, -19, -9, -19, -9, -19, -9, -20, -10, -21, -9, -21, -9, -22, -9, -21, -9, -22, -10, -22, -11, -21, -10, -21, -9, -21, -10, -21, -11, -22, -10, -21, -10, -21, -9, -20, -9, -21, -9, -20, -10, -20, -10, -19, -11, -20, -10, -20, -9, -20, -9, -19, -9, -20, -9, -19, -9, -20, -10, -21, -9, -20, -8, -20, -8, -19, -8, -19, -8, -20, -8, -21, -8, -21, -9, -20, -9, -20, -10, -20, -10, -20, -9, -20, -8, -20, -8, -20, -8, -20, -8, -20, -8, -19, -8, -20, -9, -19, -9, -19, -9, -19, -10, -18, -10, -19, -10, -20, -10, -19, -11, -19, -12, -19, -12, -20, -12, -20, -11, -20, -11, -19, -10, -20, -11, -21, -11, -20, -10, -21, -10, -21, -9, -21, -9, -21, -9, -21, -9, -20, -9, -21, -8, -21, -8, -22, -8, -22, -8, -22, -8, -22, -9, -22, -8, -21, -8, -20, -8, -20, -8, -20, -7, -20, -8, -21, -7, -22, -6, -22, -7, -21, -8, -20, -7, -20, -8, -19, -9, -18, -9, -18, -9, -18, -10, -18, -10, -19, -10, -20, -10, -19, -10, -19, -9, -18, -8, -19, -7, -19, -8, -19, -8, -20, -8, -20, -8, -21, -9, -21, -9, -21, -10, -21, -10, -20, -11, -20, -11, -20, -11, -19, -12, -20, -12, -19, -12, -20, -11, -19, -11, -19, -11, -20, -12, -21, -13, -21, -13, -21, -14, -21, -14, -22, -14, -21, -14, -21, -15, -20, -15, -21, -15, -21, -15, -21, -15, -20, -15, -20, -16, -20, -15, -19, -15, -19, -14, -20, -13, -20, -13, -19, -13, -19, -14, -18, -14, -17, -13, -16, -14, -16, -13, -15, -14, -15, -14, -14, -15, -14, -14, -14, -15, -15, -15, -16, -14, -16, -14, -17, -13, -17, -13, -17, -13, -18, -12, -19, -11, -20, -10, -20, -9, -21, -10, -21, -10, -21, -11, -22, -11, -22, -11, -22, -10, -21, -10, -21, -10, -20, -11, -21, -11, -21, -11, -20, -12, -20, -12, -20, -13, -21, -14, -22, -15, -21, -16, -20, -17, -21, -17, -21, -16, -21, -15, -21, -14, -21, -14, -22, -14, -21, -14, -21, -14, -21, -14, -20, -15, -20, -15, -20, -15, -20, -16, -19, -16, -19, -16, -20, -17, -19, -17, -18, -18, -18, -18, -19, -18, -20, -18, -20, -18, -19, -17, -19, -16, -19, -16, -19, -16, -19, -15, -18, -16, -18, -15, -19, -15, -18, -15, -18, -15, -18, -15, -18, -15, -19, -14, -20, -14, -21, -15, -21, -15, -21, -15, -22, -14, -21, -13, -22, -12, -22, -13, -23, -13, -23, -13, -22, -13, -22, -13, -22, -13, -23, -13, -23, -14, -23, -14, -24, -14, -25, -13, -25, -12, -25, -11, -25, -11, -25, -10, -24, -11, -24, -11, -23, -11, -23, -10, -22, -10, -21, -10, -20, -9, -21, -8, -22, -8, -23, -8, -23, -7, -24, -8, -25, -8, -25, -8, -26, -8, - ...

# %% [markdown]
# ### A.a. Random walk in 2D with( *use of Function*)

# %%
def R_walk2D(N,init_pos):
    
    '''if you are in (xi,yi) position go to (xf,yf)'''

    '''set up xi,yi'''
    xi = init_pos[0]
    yi = init_pos[1]

    '''store x and y into X and Y list'''
    X = [xi]
    Y = [yi]

    ''' iterate to N steps using for loop'''
    for t in range(N):
            direction =  random.choice(['x','y'])
            if direction == 'x':
                r = random.choice([-1,1])
                xf = X[t-1] + r*xi
                yf = Y[t-1]
            if direction == 'y':
                r = random.choice([-1,1])
                yf = Y[t-1] + r*yi
                xf = X[t-1]
    
            '''update X and Y in every loop'''
            X.append(xf)
            Y.append(yf)
    return X,Y

# %% [markdown]
# ### B.a. saving data to json file

# %%
''' To make a new directory called data'''
import os
os.mkdir('data')

# %%
'''Saving data which is output of the direct iterations method i.e. A.a'''

import json as json
R_walk2D_Data = {'x':X , 'y': Y}
with open ('data/R_walk2D_Data.json','w') as f:
    json.dump(R_walk2D_Data,f)

# %%
''' Saving data which is output of the function R_Walk2D(N,init_pos)i.e. A.b. in .json'''

import json as json
N = 1000
R_walk2D_Data_f = {'x':R_walk2D(N,[1,-1])[0], 'y': R_walk2D(N,[-1,1])[1]}
with open('data/R_walk2D_Data_f.json','w') as f:
    json.dump(R_walk2D_Data_f,f)

# %% [markdown]
# ### B.b. saving data to csv file

# %%
'''Creating Dataframe and saving to .CSV to the data from direct iteration method, A.a'''

R_walk2D_Data = {'x':X , 'y': Y}
R_walk2D_Data = pd.DataFrame(R_walk2D_Data)
R_walk2D_Data.to_csv('data/R_walk2D_Data.csv')

'''Creating Dataframe and saving to .CSV to the data from function method, A.b.'''

R_walk2D_Data_f = {'x':R_walk2D(N,[1,-1])[0], 'y': R_walk2D(N,[-1,1])[1]}
R_walk2D_Data_f = pd.DataFrame(R_walk2D_Data_f)
R_walk2D_Data_f.to_csv('data/R_walk2D_Data_f.csv')

# %% [markdown]
# ### C. Creating and saving the plot as (pdf/png) file

# %%
os.mkdir('Plot')

# %%
'''Make a plot for X and Y obtained from direct iteration method'''    

plt.figure(figsize = [8,8])
plt.plot(X,Y, color = 'r')
plt.xlabel("X_Walk")
plt.ylabel('Y_Walk')
plt.title("Random walk in 2D",fontsize = 15)
plt.grid(True)
plt.savefig("plot/Random walk in 2D.pdf")
plt.savefig("plot/Random walk in 2D.png")
plt.show()

# %%
'''Making a plot for X and Y obtained from using a function R_walk2D(N,init_pos)'''

N = 1000
A = R_walk2D(N,[1,-1])

plt.figure(figsize = [8,8])
plt.plot(A[0],A[1],"-")

plt.xlabel("X_Walk")
plt.ylabel('Y_Walk')
plt.title("Random walk in 2D_f",fontsize = 15)
plt.grid(True)
plt.savefig("plot/Random walk in 2D_f.pdf")
plt.savefig("plot/Random walk in 2D_f.png")
plt.show()
